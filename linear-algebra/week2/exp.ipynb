# %%
import numpy as np

# %%
A = np.array([
    [0, 2, 1],
    [1, 1, 1],
    [1, 2, 1]
], dtype=float)
A
# Out:
# array([[0., 2., 1.],
#        [1., 1., 1.],
#        [1., 2., 1.]])

# %%
B = np.array([[3], [6], [12]], dtype=float)
B
# Out:
# array([[ 3.],
#        [ 6.],
#        [12.]])

# %%
M = np.hstack((A, B))
M
# Out:
# array([[ 0.,  2.,  1.,  3.],
#        [ 1.,  1.,  1.,  6.],
#        [ 1.,  2.,  1., 12.]])

# %%
M[0]
# Out:
# array([0., 2., 1., 3.])
